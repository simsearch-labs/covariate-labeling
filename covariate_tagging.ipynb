# %%
# this version is only compatible with tag v0.0.6
# !git clone https://github.com/atlantis-nova/simtag.git
# Out:
# Cloning into 'simtag'...

# %%
import warnings

# move directory to the root of this repo
# os.chdir('\\'.join(os.getcwd().split('\\')[:-3]))
warnings.simplefilter("ignore")

import pandas as pd
from simtag.simtag.filter import simtag_filter
from sklearn.neighbors import NearestNeighbors
from sentence_transformers import SentenceTransformer
from collections import Counter
from sentence_transformers.util import cos_sim
import textwrap

# %%
# import raw data
df = pd.read_parquet('simtag/notebooks/steam-games/games.parquet').dropna()
df['Tags'] = df['Tags'].apply(lambda x : x.split(','))
df['Genres'] = df['Genres'].apply(lambda x : x.split(','))
df = df.drop(['game_vector', 'game_indices', 'Score', 'Recommendations'], axis=1)

# extract raw lists
sample_list = df['Tags'].values.tolist()

# %%
# we instatiate the model first, so we can assign it to multiple copies of the engine
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2', device='cpu')

# initiate engine
engine = simtag_filter(
	model=model
)

# %%
M, valid_tags, pointers = engine.compute_optimal_M(sample_list)
engine.load_M(M, pointers, covariate_transformation='dot_product')
engine.index_tags = engine.compute_index(data=M, k=len(engine.tag_list))
engine.index_tags
# Out:
# 100%|██████████| 446/446 [00:10<00:00, 44.22it/s]
# NearestNeighbors(metric='cosine', n_neighbors=446)

# %% [markdown]
# ### covariate tagging

# %%
def covariate_tagging(text, top_tags=100, min_window=2, max_window=7, window_length=5, mc1=1000, top_mc1=20, score_threshold=0.01, verbose=False):

	print(textwrap.fill(text, width=120))

	#
	base_vector = engine.model.encode(text)

	# find the top tags
	distances, indices = engine.index_tags.kneighbors([base_vector])

	top_tags = [engine.tag_list[x] for x in indices[0]]

	# scrolling window
	mc = list()
	min_window, max_window = window_length, window_length
	for j in range(min_window, max_window+1):
		for k in range(int(len(top_tags)/j)+1):
			ranges = [k*j, (k+1)*j]
			choice = top_tags[ranges[0]:ranges[1]]
			if len(choice) > 0:
				mc.append(choice)
	mc_encoded = engine.encode_samples(mc, quantize_samples=False, show_progress=True)
	nbrs_mc = NearestNeighbors(n_neighbors=top_mc1, metric='cosine').fit(mc_encoded)
	distances, indices = nbrs_mc.kneighbors([engine.model.encode(text)])

	results = [mc[x] for x in indices[0]]
	top_tags = [x for xs in results for x in xs] # in case we want to pass it to the next monte-carlo

	tag_freq = Counter(tag for game_tags in results for tag in game_tags)
	tag_freq = dict(tag_freq)

	top_m = sorted([[tag_freq[key], key] for index, key in enumerate(tag_freq)])[::-1]
	top_m = [x[1] for x in top_m]

	accepted = list()
	#
	best_selection_score = 0
	for m in range(len(top_m)):
		best_tag = ''
		score = 0
		for k in top_m:
			if k not in accepted:
				iteration = accepted + [k]
				vector_iteration = engine.encode_samples([iteration], quantize_samples=False, show_progress=False)[0]
				base_vector = base_vector.astype(vector_iteration.dtype)  # cast m2 to match m1's dtype
				vector_score = cos_sim(base_vector, vector_iteration).tolist()[0][0]
				if vector_score > score:
					score = vector_score
					best_tag = k
				else:
					pass
		sequence_score = score
		accepted.append(best_tag)

		if sequence_score > best_selection_score and m > 0 and ((sequence_score-best_selection_score)/best_selection_score) > score_threshold:
			best_selection_score = sequence_score
		elif m == 0:
			best_selection_score = sequence_score
		else:
			break
			# pass

	return accepted, mc

accepted, mc = covariate_tagging(df.iloc[3]['About the game'], top_tags=100, window_length=5, score_threshold=0.01, verbose=True)
accepted
# Out:
# Astro Tripper is a furious shoot-em-up experience inspired by the painful, knuckle busting video games of years gone by.
# An evolution of PomPom's 2001 award winning game, Space Tripper. Travel the surface of large horizontally-scrolling
# platforms, and pit your highly maneuverable craft against hoards of enemies eager to blow you to bits, eat you or worse.
# Gameplay is simple. You are free to travel anywhere on the platform at anytime, but don’t fall off! Powerful Blue Lasers
# and Red Spread Lasers come equipped, so use both weapons tactically to get through tricky situations. Power up your
# weapons with power crystals dropped by destroyed enemies. Oh, did we mention the blasting absolutely anything that
# moves? Enemies encountered are varied. Zippy UFOS. Fat Motherships. Tanks. Choppers. Slimy Slug creatures. Alien
# Insects. Aztec structures brimming with electricity. And of course, Big Bosses! 14 unique levels spread over 4 diverse
# worlds means there’s always something new just around the corner. Key features: Furious retro shoot-em-up gameplay 14
# completely unique levels spread over 4 worlds Vibrant 3D visuals and effects Global Online Leaderboards Unlockable
# Challenge Games Achievements
# processing samples: 100%|██████████| 90/90 [00:00<00:00, 750.08it/s]
# ['Spaceships',
#  'Tactical RPG',
#  'Card Battler',
#  'Top-Down Shooter',
#  'Aliens',
#  'Turn-Based Strategy',
#  'Open World Survival Craft',
#  'Jump Scare']

# %% [markdown]
# ### comparison with bart-large-mnli

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

# %%
sequence_to_classify = df.iloc[3]['About the game']
candidate_labels = engine.tag_list
classifier(sequence_to_classify, candidate_labels)
# Out:
# {'sequence': "'MazM: Jekyll and Hyde' is a darkly entertaining adventure game based on the classic 1886 novel 'The Strange Case of Dr. Jekyll and Mr. Hyde' by Robert Louis Stevenson, in which you'll tackle the mystery from a totally new angle! You'll travel back to 19th century London and view the city through the eyes of Mr. Utterson, a lawyer that walks the true path hunting for clues to solve a disturbing mystery, and Mr. Hyde, who has been pushed to his physical limits. Wander the streets of this psychological thriller and prepare for an ending you would never expect! The version of London presented in 'MazM: Jekyll and Hyde' has a dark, heavy atmosphere, creating a sense of the eerie and macabre. The stunning artwork and unsettling music help to further intensify the disturbing nature of the game. Travel throughout London searching for clues, and allow the world of this classic novel to envelop you as you experience the tale of one man's many challenges and potential downfall!",
#  'labels': ['Based On A Novel',
#   'Dark',
#   'Adventure',
#   'Historical',
#   'Gaming',
#   'Psychological',
#   'Immersive',
#   'Thriller',
#   'Stylized',
#   'Psychological Horror',
#   'Atmospheric',
#   'Interactive Fiction',
#   'Classic',
#   'Experience',
#   'Gothic',
#   'Horror',
#   'Massively Multiplayer',
#   'Game Development',
#   'Addictive',
#   'Surreal',
#   'Well-Written',
#   'Music',
#   'Mystery',
#   'Character Action Game',
#   'Multiple Endings',
#   'Narrative',
#   'Time Travel',
#   'Immersive Sim',
#   'Masterpiece',
#   'Moddable',
#   'Character Customization',
#   'Great Soundtrack',
#   'Mod',
#   'Board Game',
#   'Remake',
#   'RPG',
#   'Alternate History',
#   'Rogue-like',
#   'Magic',
#   'Mature',
#   'Dark Humor',
#   'Exploration',
#   'Visual Novel',
#   'Dynamic Narration',
#   'Soundtrack',
#   'Difficult',
#   'Choose Your Own Adventure',
#   'Lovecraftian',
#   'Electronic',
#   'Replay Value',
#   'Foreign',
#   'Action-Adventure',
#   'Split Screen',
#   'Old School',
#   'Silent Protagonist',
#   'Controller',
#   'Hunting',
#   'Short',
#   'Software',
#   'Utilities',
#   'Dark Comedy',
#   'Cult Classic',
#   'Dystopian',
#   'Intentionally Awkward Controls',
#   'Programming',
#   'Asymmetric VR',
#   'Musou',
#   'Audio Production',
#   'CRPG',
#   'Minigames',
#   'Ambient',
#   'Nonlinear',
#   'Narration',
#   'Action',
#   'Co-op',
#   'Cinematic',
#   'Arcade',
#   'Level Editor',
#   'JRPG',
#   'Memes',
#   'Electronic Music',
#   'Villain Protagonist',
#   'Economy',
#   'Dark Fantasy',
#   'Stealth',
#   'Crime',
#   'Emotional',
#   'Local Co-Op',
#   'TrackIR',
#   'Souls-like',
#   'Multiplayer',
#   'Retro',
#   'Online Co-Op',
#   'Otome',
#   'Satire',
#   'Tactical',
#   'Colorful',
#   'Episodic',
#   'Touch-Friendly',
#   'Music-Based Procedural Generation',
#   'Drama',
#   'Benchmark',
#   'Story Rich',
#   'Experimental',
#   'Unforgiving',
#   'Lore-Rich',
#   'Design & Illustration',
#   'Third Person',
#   'Open World',
#   'MMORPG',
#   'Building',
#   'Noir',
#   'Co-op Campaign',
#   '6DOF',
#   'Asynchronous Multiplayer',
#   'Cozy',
#   'Grid-Based Movement',
#   'Detective',
#   'Beautiful',
#   'Local Multiplayer',
#   '4 Player Local',
#   'Movie',
#   'Hentai',
#   'Management',
#   'GameMaker',
#   'Conversation',
#   'Naval',
#   'Heist',
#   'Underground',
#   'Indie',
#   'Crowdfunded',
#   'Investigation',
#   'Class-Based',
#   'Flight',
#   'Pool',
#   'Military',
#   'Fast-Paced',
#   'Shooter',
#   'Instrumental Music',
#   'Supernatural',
#   'Linear',
#   'Spelling',
#   'Sequel',
#   'Voice Control',
#   'Wholesome',
#   'Casual',
#   'Nostalgia',
#   'Documentary',
#   'Time Manipulation',
#   'Hardware',
#   'Voxel',
#   'Transportation',
#   'FMV',
#   'RTS',
#   'Blood',
#   '4X',
#   'PvE',
#   'Crafting',
#   'Rhythm',
#   'Bowling',
#   'Psychedelic',
#   'Hobby Sim',
#   'Faith',
#   'Medical Sim',
#   'Hacking',
#   'Western',
#   'First-Person',
#   'Outbreak Sim',
#   'Sexual Content',
#   'Minimalist',
#   'Reboot',
#   'Abstract',
#   'Colony Sim',
#   'Fantasy',
#   'RPGMaker',
#   'Philosophical',
#   'Quick-Time Events',
#   'Early Access',
#   '360 Video',
#   'Realistic',
#   'Violent',
#   'Political',
#   'Parody',
#   'Epic',
#   'LGBTQ+',
#   'Mining',
#   'Assassin',
#   'Mechs',
#   'Tabletop',
#   'Gore',
#   'Real-Time',
#   'Female Protagonist',
#   'Kickstarter',
#   'FPS',
#   'Logic',
#   'Loot',
#   'Modern',
#   'Web Publishing',
#   'Idler',
#   'Gun Customization',
#   'Spectacle fighter',
#   'Trading',
#   'Team-Based',
#   'Competitive',
#   'Nature',
#   'NSFW',
#   'Strategy',
#   'VR',
#   '3D Vision',
#   'Pixel Graphics',
#   'Submarine',
#   'Illuminati',
#   'Automation',
#   'Rogue-lite',
#   'Side Scroller',
#   'Simulation',
#   'Hidden Object',
#   'Science',
#   'Isometric',
#   'Party',
#   'Motorbike',
#   'Action Roguelike',
#   'Party-Based RPG',
#   'Offroad',
#   'War',
#   'Sokoban',
#   'Hand-drawn',
#   'Fighting',
#   'Action RPG',
#   'Real-Time with Pause',
#   'Turn-Based',
#   'Score Attack',
#   'Hockey',
#   'Video Production',
#   'Medieval',
#   'Resource Management',
#   'Precision Platformer',
#   'Steampunk',
#   'Transhumanism',
#   'Auto Battler',
#   'Runner',
#   'Lemmings',
#   'Politics',
#   'ATV',
#   'Sandbox',
#   'Collectathon',
#   'PvP',
#   'Social Deduction',
#   'Life Sim',
#   'Roguevania',
#   'City Builder',
#   'Horses',
#   'Steam Machine',
#   'Destruction',
#   'Traditional Roguelike',
#   'Bikes',
#   'Animation & Modeling',
#   'Mythology',
#   'Vampire',
#   'Education',
#   'Shop Keeper',
#   'Funny',
#   'Typing',
#   'Match 3',
#   'Fox',
#   'Tanks',
#   'Procedural Generation',
#   'Boss Rush',
#   'Bullet Hell',
#   'Survival Horror',
#   'Swordplay',
#   'Nudity',
#   'Survival',
#   'Perma Death',
#   '3D',
#   'Singleplayer',
#   'Conspiracy',
#   'Snow',
#   'Games Workshop',
#   'Political Sim',
#   'Jet',
#   'Cycling',
#   'Rugby',
#   'Farming',
#   'Cold War',
#   'Bullet Time',
#   '2.5D',
#   'God Game',
#   'Agriculture',
#   'Diplomacy',
#   'Walking Simulator',
#   'Romance',
#   'Creature Collector',
#   'Time Attack',
#   'Combat',
#   'BMX',
#   'Cartoony',
#   '2D',
#   'Looter Shooter',
#   'Mars',
#   'Cats',
#   'Cartoon',
#   'Driving',
#   'Choices Matter',
#   '8-bit Music',
#   'Coding',
#   'Photo Editing',
#   'Anime',
#   'Text-Based',
#   'Tactical RPG',
#   'Clicker',
#   'Sniper',
#   'Feature Film',
#   'Archery',
#   'Comic Book',
#   'Wargame',
#   'Werewolves',
#   'Jump Scare',
#   'Tutorial',
#   'Wrestling',
#   'Turn-Based Tactics',
#   'Parkour',
#   'Dog',
#   'Martial Arts',
#   'Time Management',
#   'Sports',
#   'Sailing',
#   'Trains',
#   'e-sports',
#   'Puzzle',
#   'Cricket',
#   'Vehicular Combat',
#   'Card Game',
#   'Birds',
#   'Space',
#   'Hero Shooter',
#   'Point & Click',
#   'Comedy',
#   'VR Only',
#   'Racing',
#   'Vikings',
#   'Rock Music',
#   'Party Game',
#   'Capitalism',
#   'Dating Sim',
#   'Battle Royale',
#   'Action RTS',
#   'Physics',
#   "Beat 'em up",
#   'Naval Combat',
#   'Card Battler',
#   'Superhero',
#   'Sci-fi',
#   'Gambling',
#   'Top-Down',
#   'Demons',
#   'Arena Shooter',
#   'Base-Building',
#   'Grand Strategy',
#   'Fishing',
#   'Cooking',
#   'Boxing',
#   'Hack and Slash',
#   '3D Platformer',
#   'Real Time Tactics',
#   'Underwater',
#   'Golf',
#   'On-Rails Shooter',
#   'Word Game',
#   'Artificial Intelligence',
#   'Mouse only',
#   'Pirates',
#   'Software Training',
#   'Top-Down Shooter',
#   'Motocross',
#   'Mystery Dungeon',
#   'Football (American)',
#   'Turn-Based Combat',
#   'Deckbuilding',
#   'Inventory Management',
#   'Combat Racing',
#   'Robots',
#   'Trivia',
#   'Strategy RPG',
#   'Mahjong',
#   'Puzzle-Platformer',
#   'Tower Defense',
#   'Aliens',
#   'Escape Room',
#   'Cyberpunk',
#   'Third-Person Shooter',
#   'Extraction Shooter',
#   'Farming Sim',
#   '2D Platformer',
#   'Football',
#   'MOBA',
#   "1990's",
#   'Batman',
#   'Dragons',
#   '3D Fighter',
#   'Platformer',
#   'Futuristic',
#   'Skating',
#   'Zombies',
#   'Post-apocalyptic',
#   '2D Fighter',
#   'Open World Survival Craft',
#   'Turn-Based Strategy',
#   'Basketball',
#   'Metroidvania',
#   'Warhammer 40K',
#   'Spaceships',
#   'Automobile Sim',
#   'Hex Grid',
#   'Space Sim',
#   'Tennis',
#   'Chess',
#   'Ninja',
#   'Baseball',
#   'Rome',
#   '1980s',
#   "Shoot 'Em Up",
#   'Skiing',
#   'Twin Stick Shooter',
#   'LEGO',
#   'Skateboarding',
#   'Cute',
#   'Roguelike Deckbuilder',
#   'Job Simulator',
#   'Dinosaurs',
#   'Dungeon Crawler',
#   'Pinball',
#   'Soccer',
#   'Volleyball',
#   'America',
#   'Football (Soccer)',
#   'Relaxing',
#   'World War I',
#   'Free to Play',
#   'Trading Card Game',
#   'Dungeons & Dragons',
#   'Solitaire',
#   'Snowboarding',
#   'Mini Golf',
#   'Family Friendly',
#   'World War II'],
#  'scores': [0.15721455216407776,
#   0.04416581615805626,
#   0.04065808281302452,
#   0.022500157356262207,
#   0.022270139306783676,
#   0.02072121948003769,
#   0.01674828864634037,
#   0.01366274245083332,
#   0.011373692192137241,
#   0.010487673804163933,
#   0.010153069160878658,
#   0.008959162048995495,
#   0.008717965334653854,
#   0.008680172264575958,
#   0.007320533040910959,
#   0.007198874372988939,
#   0.0069398218765854836,
#   0.006858896464109421,
#   0.0068413978442549706,
#   0.006755751557648182,
#   0.006733629386872053,
#   0.006449233274906874,
#   0.005510122049599886,
#   0.005450131371617317,
#   0.005242897197604179,
#   0.00513820443302393,
#   0.005051031243056059,
#   0.004417718388140202,
#   0.0043715182691812515,
#   0.0042993673123419285,
#   0.0040808930061757565,
#   0.003994094207882881,
#   0.00398546876385808,
#   0.003897157497704029,
#   0.0038863159716129303,
#   0.0038859930355101824,
#   0.0038397477474063635,
#   0.0037497663870453835,
#   0.003674037056043744,
#   0.003662809729576111,
#   0.0035953554324805737,
#   0.0035871940199285746,
#   0.0034338042605668306,
#   0.003410340053960681,
#   0.003355214837938547,
#   0.003329421393573284,
#   0.0033293869346380234,
#   0.003210428636521101,
#   0.003169837174937129,
#   0.003157850820571184,
#   0.0031531518325209618,
#   0.0030344969127327204,
#   0.0030309122521430254,
#   0.0030070794746279716,
#   0.0028418453875929117,
#   0.002839714754372835,
#   0.0028292278293520212,
#   0.002810568315908313,
#   0.0027786134742200375,
#   0.0027606829535216093,
#   0.0026880998630076647,
#   0.0026799228508025408,
#   0.0026751153636723757,
#   0.002639868762344122,
#   0.00262068840675056,
#   0.0003024110337719321,
#   0.00028523578657768667,
#   0.0002779443166218698,
#   0.0002734467852860689,
#   0.0002726303937379271,
#   0.00027175885043106973,
#   0.0002577914856374264,
#   0.00021040774299763143,
#   0.00018727005226537585]}

# %% [markdown]
# ### comparison with zero-shot-implicit-bi-encoder

# %%
from sentence_transformers import SentenceTransformer, util as sbert_util

model = SentenceTransformer(model_name_or_path='claritylab/zero-shot-implicit-bi-encoder')

# %%
text = df.iloc[3]['About the game']
labels = engine.tag_list
aspect = 'best tag:' # classification
aspect_sep_token = model.tokenizer.additional_special_tokens[0]
text = f'{aspect} {aspect_sep_token} {text}'

text_embed = model.encode(text)
label_embeds = model.encode(labels)
scores = [round(sbert_util.cos_sim(text_embed, lb_embed).item(), 3) for lb_embed in label_embeds]
sorted(list(zip(scores, labels)))[::-1]
# Out:
# [(0.871, 'Feature Film'),
#  (0.851, 'Thriller'),
#  (0.845, 'Documentary'),
#  (0.832, 'Dark Comedy'),
#  (0.813, 'Action RPG'),
#  (0.791, 'Cinematic'),
#  (0.774, "1990's"),
#  (0.731, 'Action Roguelike'),
#  (0.706, 'RPG'),
#  (0.696, 'On-Rails Shooter'),
#  (0.695, 'Based On A Novel'),
#  (0.691, 'Drama'),
#  (0.629, 'Movie'),
#  (0.614, 'Strategy RPG'),
#  (0.609, 'Remake'),
#  (0.596, 'Sci-fi'),
#  (0.568, 'Action-Adventure'),
#  (0.554, 'Party-Based RPG'),
#  (0.531, 'Tactical RPG'),
#  (0.525, 'Video Production'),
#  (0.498, 'MMORPG'),
#  (0.492, 'RPGMaker'),
#  (0.477, 'Short'),
#  (0.477, 'Sequel'),
#  (0.448, 'Epic'),
#  (0.443, 'Dungeon Crawler'),
#  (0.44, 'Character Action Game'),
#  (0.427, 'Anime'),
#  (0.417, 'Fox'),
#  (0.403, 'VR Only'),
#  (0.391, 'Cult Classic'),
#  (0.39, 'Interactive Fiction'),
#  (0.385, 'Immersive Sim'),
#  (0.384, 'Comedy'),
#  (0.348, 'Mystery Dungeon'),
#  (0.336, 'Episodic'),
#  (0.333, 'Visual Novel'),
#  (0.326, '360 Video'),
#  (0.323, 'Indie'),
#  (0.313, 'Arcade'),
#  (0.313, '3D Fighter'),
#  (0.309, 'Cartoon'),
#  (0.306, '3D Platformer'),
#  (0.298, 'Offroad'),
#  (0.297, 'Well-Written'),
#  (0.293, 'Dark Fantasy'),
#  (0.289, 'Dungeons & Dragons'),
#  (0.288, 'Retro'),
#  (0.288, 'Immersive'),
#  (0.286, 'Hero Shooter'),
#  (0.277, 'Co-op'),
#  (0.276, 'Comic Book'),
#  (0.275, 'Split Screen'),
#  (0.273, 'Web Publishing'),
#  (0.271, 'Choose Your Own Adventure'),
#  (0.27, 'Game Development'),
#  (0.268, 'Audio Production'),
#  (0.266, 'Steampunk'),
#  (0.264, 'Job Simulator'),
#  (0.261, 'Story Rich'),
#  (0.257, 'Minigames'),
#  (0.255, 'Survival Horror'),
#  (0.254, 'Board Game'),
#  (0.253, 'GameMaker'),
#  (0.252, 'Level Editor'),
#  (0.244, 'Hentai'),
#  (0.243, 'Dystopian'),
#  (0.242, 'Warhammer 40K'),
#  (0.238, 'Masterpiece'),
#  (0.238, 'Cartoony'),
#  (0.237, '1980s'),
#  (0.235, 'Fast-Paced'),
#  (0.233, 'Realistic'),
#  (0.232, 'Reboot'),
#  (0.229, 'Photo Editing'),
#  (0.223, 'Narrative'),
#  (0.223, 'Games Workshop'),
#  (0.221, 'Post-apocalyptic'),
#  (0.216, 'Grand Strategy'),
#  (0.213, 'Unforgiving'),
#  (0.212, 'Sokoban'),
#  (0.212, 'Nostalgia'),
#  (0.21, 'VR'),
#  (0.21, 'Futuristic'),
#  (0.207, 'Simulation'),
#  (0.206, 'Loot'),
#  (0.203, 'Noir'),
#  (0.203, 'Lovecraftian'),
#  (0.202, 'Narration'),
#  (0.202, 'Beautiful'),
#  (0.201, 'Cute'),
#  (0.201, 'Adventure'),
#  (0.2, 'Action'),
#  (0.199, 'Magic'),
#  (0.198, 'Multiple Endings'),
#  (0.197, 'Party'),
#  (0.195, 'Pixel Graphics'),
#  (0.194, 'Music-Based Procedural Generation'),
#  (0.194, 'First-Person'),
#  (0.193, 'Collectathon'),
#  (0.192, 'Dynamic Narration'),
#  (0.19, 'Silent Protagonist'),
#  (0.189, 'Programming'),
#  (0.187, 'Rome'),
#  (0.186, '2D Platformer'),
#  (0.185, 'Touch-Friendly'),
#  (0.185, 'JRPG'),
#  (0.182, 'Villain Protagonist'),
#  (0.182, 'Female Protagonist'),
#  (0.182, 'Family Friendly'),
#  (0.182, 'Classic'),
#  (0.178, '3D Vision'),
#  (0.176, 'Action RTS'),
#  (0.173, 'Roguevania'),
#  (0.173, 'Gothic'),
#  (0.173, 'Dark Humor'),
#  (0.173, 'Casual'),
#  (0.172, '3D'),
#  (0.171, 'Third-Person Shooter'),
#  (0.17, 'Great Soundtrack'),
#  (0.169, 'Satire'),
#  (0.167, 'Strategy'),
#  (0.165, 'Rogue-lite'),
#  (0.165, 'Mouse only'),
#  (0.164, 'Lore-Rich'),
#  (0.164, 'Difficult'),
#  (0.162, 'Looter Shooter'),
#  (0.16, 'Supernatural'),
#  (0.16, 'Emotional'),
#  (0.159, 'Memes'),
#  (0.158, 'Software Training'),
#  (0.156, 'Hand-drawn'),
#  (0.156, 'Destruction'),
#  (0.153, 'Capitalism'),
#  (0.151, 'Gaming'),
#  (0.149, 'Software'),
#  (0.149, 'Cyberpunk'),
#  (0.148, 'Trivia'),
#  (0.146, 'Parody'),
#  (0.145, 'Turn-Based Strategy'),
#  (0.145, 'Conversation'),
#  (0.144, 'Nonlinear'),
#  (0.143, 'Side Scroller'),
#  (0.143, 'Blood'),
#  (0.142, 'Online Co-Op'),
#  (0.142, 'Asynchronous Multiplayer'),
#  (0.139, 'Space Sim'),
#  (0.138, 'Tactical'),
#  (0.138, 'Procedural Generation'),
#  (0.137, 'Fantasy'),
#  (0.136, 'Hardware'),
#  (0.134, 'Sexual Content'),
#  (0.133, 'Psychological Horror'),
#  (0.133, 'Party Game'),
#  (0.133, 'Artificial Intelligence'),
#  (0.131, 'CRPG'),
#  (0.13, 'Voxel'),
#  (0.13, 'Heist'),
#  (0.13, 'Gore'),
#  (0.129, 'Horror'),
#  (0.129, 'Grid-Based Movement'),
#  (0.128, 'Experience'),
#  (0.128, 'Design & Illustration'),
#  (0.126, 'Funny'),
#  (0.126, 'Demons'),
#  (0.125, 'Wargame'),
#  (0.125, 'Turn-Based Tactics'),
#  (0.125, 'Rhythm'),
#  (0.125, 'Alternate History'),
#  (0.124, 'Zombies'),
#  (0.124, 'Real Time Tactics'),
#  (0.124, 'Coding'),
#  (0.124, 'Boss Rush'),
#  (0.121, 'Spectacle fighter'),
#  (0.12, 'Word Game'),
#  (0.12, 'Pirates'),
#  (0.12, 'Massively Multiplayer'),
#  (0.12, 'Benchmark'),
#  (0.119, 'Relaxing'),
#  (0.119, 'Perma Death'),
#  (0.117, 'Romance'),
#  (0.116, 'MOBA'),
#  (0.116, 'Farming Sim'),
#  (0.114, 'Creature Collector'),
#  (0.113, "Shoot 'Em Up"),
#  (0.113, 'Moddable'),
#  (0.113, 'Local Co-Op'),
#  (0.111, 'Asymmetric VR'),
#  (0.109, 'God Game'),
#  (0.108, 'Local Multiplayer'),
#  (0.108, 'Historical'),
#  (0.107, 'NSFW'),
#  (0.106, 'Survival'),
#  (0.106, 'Musou'),
#  (0.106, 'City Builder'),
#  (0.106, 'America'),
#  (0.105, 'Colony Sim'),
#  (0.104, 'Souls-like'),
#  (0.104, 'Philosophical'),
#  (0.104, 'Choices Matter'),
#  (0.103, 'Controller'),
#  (0.102, 'Hack and Slash'),
#  (0.102, 'Co-op Campaign'),
#  (0.101, 'Psychedelic'),
#  (0.101, 'Clicker'),
#  (0.099, 'Spaceships'),
#  (0.099, 'Gambling'),
#  (0.097, 'Hidden Object'),
#  (0.097, 'Economy'),
#  (0.097, 'Animation & Modeling'),
#  (0.096, 'Battle Royale'),
#  (0.096, 'Agriculture'),
#  (0.095, 'Shooter'),
#  (0.095, 'Lemmings'),
#  (0.093, 'War'),
#  (0.093, 'Rogue-like'),
#  (0.093, 'Medieval'),
#  (0.093, 'Jump Scare'),
#  (0.093, 'Hacking'),
#  (0.093, 'FPS'),
#  (0.092, 'Underwater'),
#  (0.092, 'Puzzle-Platformer'),
#  (0.092, 'Psychological'),
#  (0.092, 'Mahjong'),
#  (0.092, 'Intentionally Awkward Controls'),
#  (0.092, 'Diplomacy'),
#  (0.089, 'World War I'),
#  (0.089, 'Farming'),
#  (0.089, "Beat 'em up"),
#  (0.088, 'World War II'),
#  (0.088, 'Point & Click'),
#  (0.087, 'Stealth'),
#  (0.087, 'Sandbox'),
#  (0.087, 'Cozy'),
#  (0.087, 'Combat'),
#  (0.087, 'Character Customization'),
#  (0.086, 'Transhumanism'),
#  (0.086, 'Modern'),
#  (0.085, 'Crafting'),
#  (0.084, 'Open World'),
#  (0.084, 'Kickstarter'),
#  (0.083, 'Space'),
#  (0.083, '8-bit Music'),
#  (0.082, 'Werewolves'),
#  (0.082, 'Typing'),
#  (0.082, 'Turn-Based Combat'),
#  (0.081, 'Traditional Roguelike'),
#  (0.081, 'Real-Time with Pause'),
#  (0.081, 'Idler'),
#  (0.079, 'Metroidvania'),
#  (0.078, 'Time Management'),
#  (0.077, 'Logic'),
#  (0.076, 'Aliens'),
#  (0.074, 'Addictive'),
#  (0.074, '6DOF'),
#  (0.073, 'Platformer'),
#  (0.073, 'Fighting'),
#  (0.073, 'Crime'),
#  (0.072, 'Violent'),
#  (0.072, 'Mining'),
#  (0.072, 'Driving'),
#  (0.072, 'Conspiracy'),
#  (0.071, 'Multiplayer'),
#  (0.071, 'Faith'),
#  (0.07, 'Surreal'),
#  (0.069, 'Detective'),
#  (0.068, 'Mythology'),
#  (0.068, 'Early Access'),
#  (0.067, 'Real-Time'),
#  (0.066, 'Top-Down Shooter'),
#  (0.066, 'Time Attack'),
#  (0.066, 'Sniper'),
#  (0.066, 'Open World Survival Craft'),
#  (0.066, 'Crowdfunded'),
#  (0.065, 'Time Manipulation'),
#  (0.065, 'Third Person'),
#  (0.065, 'Automation'),
#  (0.064, 'Assassin'),
#  (0.063, 'Walking Simulator'),
#  (0.063, 'Outbreak Sim'),
#  (0.063, 'Dating Sim'),
#  (0.063, 'Colorful'),
#  (0.062, 'Illuminati'),
#  (0.062, 'Extraction Shooter'),
#  (0.062, 'Dragons'),
#  (0.061, 'Wholesome'),
#  (0.061, 'Ninja'),
#  (0.061, '2D'),
#  (0.06, 'Old School'),
#  (0.06, 'Class-Based'),
#  (0.059, 'Tower Defense'),
#  (0.059, 'Tanks'),
#  (0.058, '4 Player Local'),
#  (0.057, 'Medical Sim'),
#  (0.057, 'Dark'),
#  (0.056, 'Cold War'),
#  (0.055, 'Science'),
#  (0.055, 'Exploration'),
#  (0.055, 'Experimental'),
#  (0.054, 'Score Attack'),
#  (0.054, 'Minimalist'),
#  (0.054, 'Bullet Hell'),
#  (0.054, '2D Fighter'),
#  (0.053, 'Resource Management'),
#  (0.053, 'Abstract'),
#  (0.052, 'Political Sim'),
#  (0.052, 'Combat Racing'),
#  (0.051, 'Hobby Sim'),
#  (0.051, 'Free to Play'),
#  (0.05, 'Life Sim'),
#  (0.05, 'Investigation'),
#  (0.047, 'Nudity'),
#  (0.047, 'LEGO'),
#  (0.046, 'PvP'),
#  (0.045, 'Vehicular Combat'),
#  (0.045, 'Soundtrack'),
#  (0.044, 'Western'),
#  (0.044, 'Tutorial'),
#  (0.044, 'Naval Combat'),
#  (0.043, 'Trading Card Game'),
#  (0.043, 'Dinosaurs'),
#  (0.042, 'Team-Based'),
#  (0.042, 'Electronic'),
#  (0.041, 'LGBTQ+'),
#  (0.041, 'Inventory Management'),
#  (0.041, 'Arena Shooter'),
#  (0.04, 'Political'),
#  (0.04, 'Batman'),
#  (0.039, 'Replay Value'),
#  (0.038, 'Twin Stick Shooter'),
#  (0.038, 'Superhero'),
#  (0.037, 'Utilities'),
#  (0.037, 'Swordplay'),
#  (0.037, 'Politics'),
#  (0.036, 'Auto Battler'),
#  (0.035, 'Hex Grid'),
#  (0.034, 'Voice Control'),
#  (0.034, 'Management'),
#  (0.034, 'Linear'),
#  (0.034, 'Education'),
#  (0.033, 'Runner'),
#  (0.033, 'Physics'),
#  (0.033, 'Instrumental Music'),
#  (0.032, 'Gun Customization'),
#  (0.031, 'Vampire'),
#  (0.031, 'Music'),
#  (0.031, '4X'),
#  (0.03, 'Nature'),
#  (0.03, 'Mechs'),
#  (0.03, 'Fishing'),
#  (0.029, 'e-sports'),
#  (0.029, 'Precision Platformer'),
#  (0.027, 'Roguelike Deckbuilder'),
#  (0.026, 'Mod'),
#  (0.026, 'Escape Room'),
#  (0.026, 'Competitive'),
#  (0.025, 'TrackIR'),
#  (0.025, 'Racing'),
#  (0.025, 'Military'),
#  (0.025, '2.5D'),
#  (0.024, 'Vikings'),
#  (0.023, 'Parkour'),
#  (0.023, 'Hunting'),
#  (0.023, 'Football (American)'),
#  (0.021, 'Rock Music'),
#  (0.021, 'Martial Arts'),
#  (0.021, 'Mars'),
#  (0.021, 'Bikes'),
#  (0.02, 'Tabletop'),
#  (0.02, 'Horses'),
#  (0.019, 'Mature'),
#  (0.019, 'Cats'),
#  (0.018, 'Underground'),
#  (0.018, 'Naval'),
#  (0.017, 'Top-Down'),
#  (0.017, 'Pinball'),
#  (0.017, 'Football (Soccer)'),
#  (0.017, 'Basketball'),
#  (0.017, 'ATV'),
#  (0.016, 'Time Travel'),
#  (0.016, 'Text-Based'),
#  (0.016, 'Rugby'),
#  (0.016, 'Football'),
#  (0.015, 'Soccer'),
#  (0.015, 'Pool'),
#  (0.015, 'Cycling'),
#  (0.015, 'Automobile Sim'),
#  (0.014, 'Sports'),
#  (0.014, 'Cricket'),
#  (0.013, 'Wrestling'),
#  (0.013, 'Hockey'),
#  (0.012, 'Robots'),
#  (0.012, 'Motocross'),
#  (0.011, 'Motorbike'),
#  (0.01, 'Electronic Music'),
#  (0.009, 'Tennis'),
#  (0.009, 'Baseball'),
#  (0.008, 'Stylized'),
#  (0.008, 'Singleplayer'),
#  (0.008, 'RTS'),
#  (0.008, 'Otome'),
#  (0.008, 'Isometric'),
#  (0.008, 'FMV'),
#  (0.007, 'Volleyball'),
#  (0.007, 'Skating'),
#  (0.007, 'Skateboarding'),
#  (0.007, 'PvE'),
#  (0.007, 'Chess'),
#  (0.007, 'Archery'),
#  (0.006, 'Dog'),
#  (0.006, 'Boxing'),
#  (0.005, 'Steam Machine'),
#  (0.005, 'Solitaire'),
#  (0.005, 'BMX'),
#  (0.004, 'Birds'),
#  (0.003, 'Sailing'),
#  (0.002, 'Card Game'),
#  (0.001, 'Match 3'),
#  (0.001, 'Jet'),
#  (0.001, 'Bowling'),
#  (0.0, 'Submarine'),
#  (0.0, 'Foreign'),
#  (0.0, 'Deckbuilding'),
#  (-0.001, 'Trading'),
#  (-0.001, 'Golf'),
#  (-0.001, 'Base-Building'),
#  (-0.002, 'Card Battler'),
#  (-0.002, 'Bullet Time'),
#  (-0.003, 'Mini Golf'),
#  (-0.004, 'Skiing'),
#  (-0.006, 'Trains'),
#  (-0.006, 'Social Deduction'),
#  (-0.006, 'Building'),
#  (-0.007, 'Turn-Based'),
#  (-0.008, 'Spelling'),
#  (-0.009, 'Snowboarding'),
#  (-0.009, 'Snow'),
#  (-0.009, 'Flight'),
#  (-0.009, 'Ambient'),
#  (-0.012, 'Puzzle'),
#  (-0.017, 'Quick-Time Events'),
#  (-0.017, 'Cooking'),
#  (-0.017, 'Atmospheric'),
#  (-0.021, 'Transportation'),
#  (-0.024, 'Shop Keeper'),
#  (-0.027, 'Mystery')]
